# %%
# -------------------------------
# Assignment 4: Statistics & Probability
# -------------------------------

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load cleaned dataset
data = pd.read_csv("creditcard_cleaned.csv") 
data.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  127294.0 -2.537331  1.890864 -0.840555 -1.102759 -2.105725  0.367811
# 1  117632.0 -0.250839  1.104108  0.206089  0.417324  1.204079 -0.350694
# 2  148330.0  0.568980 -2.520416 -1.114138  1.670652 -1.128945  0.398822
# 3   67778.0  1.328892  0.226908 -0.308968  0.381772  0.238490 -0.282946
# 4    6308.0  1.124863 -0.165691  1.337053  1.030033 -0.891116  0.202926
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0 -2.737844 -3.543314 -0.483147  ...  4.328165 -2.167329  1.022567 -0.241143
# 1  1.369769 -0.133535 -0.957100  ...  0.133048  0.499501 -0.392572 -0.393364
# 2  0.190403  0.161493  0.840595  ...  0.318037 -0.760732 -0.181332  0.595866
# 3  0.029460 -0.079962  0.227173  ... -0.379270 -1.148959 -0.047403 -1.074464
# 4 -0.825094  0.163280  2.301808  ... -0.216512 -0.195607  0.072785  0.045625
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
print("\n=== Basic Statistics ===")

# Mean
mean_values = data.mean(numeric_only=True)
print("\nMean:\n", mean_values)
# Out:
# === Basic Statistics ===
#
# Mean:
#  Time      94617.008381
# V1            0.005363
# V2            0.002703
# V3            0.003257
# V4           -0.001904
# V5            0.000363
# V6           -0.001286
# V7            0.001047
# V8            0.002983
# V9           -0.005628
# V10          -0.002403
# V11           0.002990
# V12          -0.002408
# V13           0.002738
# V14           0.002594
# V15          -0.002921
# V16           0.005247
# V17          -0.000769
# V18           0.001511
# V19          -0.000728
# V20           0.002157
# V21          -0.001472
# V22          -0.000767
# V23          -0.001624
# V24           0.000117
# V25           0.001173
# V26          -0.000109
# V27           0.001887
# V28          -0.000666
# Amount        3.148509
# Class         0.001700
# dtype: float64

# %%
# Median
median_values = data.median(numeric_only=True)
print("\nMedian:\n", median_values)
# Out:
# Median:
#  Time      84517.000000
# V1            0.020241
# V2            0.067436
# V3            0.178129
# V4           -0.018543
# V5           -0.052851
# V6           -0.275513
# V7            0.039590
# V8            0.020606
# V9           -0.053539
# V10          -0.092681
# V11          -0.030845
# V12           0.138452
# V13          -0.011036
# V14           0.054819
# V15           0.045547
# V16           0.070674
# V17          -0.066688
# V18          -0.002855
# V19           0.002282
# V20          -0.061905
# V21          -0.030292
# V22           0.007661
# V23          -0.012376
# V24           0.040560
# V25           0.016953
# V26          -0.052332
# V27           0.001281
# V28           0.011199
# Amount        3.135059
# Class         0.000000
# dtype: float64

# %%
# Mode
mode_values = data.mode(numeric_only=True).iloc[0]
print("\nMode:\n", mode_values)
# Out:
# Mode:
#  Time      3760.000000
# V1           1.245674
# V2           0.166975
# V3           0.488306
# V4           0.635322
# V5          -0.562777
# V6          -1.011073
# V7           0.014953
# V8          -0.160211
# V9           0.170362
# V10         -0.044575
# V11         -0.356749
# V12         -0.073460
# V13         -0.517760
# V14          0.406969
# V15          1.124147
# V16          0.342470
# V17         -0.374656
# V18         -0.438992
# V19         -0.116091
# V20         -0.132080
# V21         -0.262581
# V22         -0.816264
# V23          0.140304
# V24          0.357827
# V25          0.186423
# V26          0.096544
# V27         -0.035866
# V28          0.018495
# Amount       0.693147
# Class        0.000000
# Name: 0, dtype: float64

# %%
# Variance
variance_values = data.var(numeric_only=True)
print("\nVariance:\n", variance_values)
# Out:
# Variance:
#  Time      2.254569e+09
# V1        3.755950e+00
# V2        2.668680e+00
# V3        2.268713e+00
# V4        1.996846e+00
# V5        1.856588e+00
# V6        1.747433e+00
# V7        1.457774e+00
# V8        1.380758e+00
# V9        1.200940e+00
# V10       1.160372e+00
# V11       1.038204e+00
# V12       9.897400e-01
# V13       9.952059e-01
# V14       9.067568e-01
# V15       8.377349e-01
# V16       7.667950e-01
# V17       7.266287e-01
# V18       6.968452e-01
# V19       6.613099e-01
# V20       5.726292e-01
# V21       5.101111e-01
# V22       5.242456e-01
# V23       3.879544e-01
# V24       3.683816e-01
# V25       2.712697e-01
# V26       2.326152e-01
# V27       1.512645e-01
# V28       1.080380e-01
# Amount    2.748962e+00
# Class     1.696834e-03
# dtype: float64

# %%
# Calculate correlation of all features with target variable 'Class'
corr_matrix = data.corr()

# Sort correlation values (absolute) to find most related features
corr_with_class = corr_matrix["Class"].abs().sort_values(ascending=False)
print(corr_with_class.head(10))
# Out:
# Class    1.000000
# V17      0.313478
# V14      0.287923
# V12      0.241537
# V10      0.199670
# V16      0.184689
# V3       0.175592
# V7       0.174632
# V11      0.143237
# V4       0.120303
# Name: Class, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, cmap='coolwarm', center=0)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
top_features = corr_with_class[1:4].index  # Skip 'Class' itself
print("Top 3 correlated features:", top_features.tolist())

# Plot distribution for each
for feature in top_features:
    plt.figure(figsize=(6,4))
    sns.boxplot(x='Class', y=feature, data=data)
    plt.title(f'{feature} vs Class')
    plt.show()
# Out:
# Top 3 correlated features: ['V17', 'V14', 'V12']
